# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from cluster_tools import *

# %% [markdown]
# ## Abrindo dados

# %%
df = pd.read_parquet(path="./../data/clean_data/df_cluster_kmeans_3.parquet")
df
# Out:
#        comdate_diff   price  freight_value  \
# 0                11  289.00          46.48
# 1               -28  259.90          22.31
# 2               -17   14.99           7.78
# 3                17   25.00          14.10
# 4                 7   99.90          22.57
# ...             ...     ...            ...
# 87849            -8   55.00          20.88
# 87850             3  114.90          14.16
# 87851             7   37.00          19.04
# 87852           -21  689.00          22.07
# 87853            -6   13.99           7.78
#
#        commercial_dates_day_since_year_start  commercial_dates_year  \
# 0                                          0                   2018
# 1                                        284                   2017
# 2                                         66                   2018
# 3                                          0                   2018
# 4                                          0                   2018
# ...

# %% [markdown]
# ## EDA

# %%
cluster_colors = ['blue', 'green', 'red'] 
visualize_all_features(df.drop(columns=["hue"]), n_clusters=3, cluster_colors=cluster_colors)

# %%
ax = sns.scatterplot(df, x="commercial_dates_day_since_year_start", y="order_purchase_day_since_year_start", hue="hue")
ax.set_xlabel("dia do ano da data comercial")
ax.set_ylabel("dia do ano da compra")
# Out:
# Text(0, 0.5, 'dia do ano da compra')

# %%
ax = sns.scatterplot(df, x="order_purchase_day_since_year_start", y="price", hue="hue")
ax.set_xlabel("dia do ano da compra")
ax.set_ylabel("preço")
# Out:
# Text(0, 0.5, 'preço')
