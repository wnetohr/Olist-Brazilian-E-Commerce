# %%
import seaborn as sns
import pandas as pd
import numpy as np
from math import ceil
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from cluster_tools import *

random_state = 42
score_types=["silhouette", "calinski_harabasz", "davies_bouldin"]

# %%
df_original = pd.read_parquet(path="./../../data/cluster_data/category_seasonal_data.parquet")
df = df_original.copy()
df
# Out:
#        comdate_diff   price  freight_value  \
# 0                11  289.00          46.48
# 1               -28  259.90          22.31
# 2               -17   14.99           7.78
# 3                17   25.00          14.10
# 4                 7   99.90          22.57
# ...             ...     ...            ...
# 87849            -8   55.00          20.88
# 87850             3  114.90          14.16
# 87851             7   37.00          19.04
# 87852           -21  689.00          22.07
# 87853            -6   13.99           7.78
#
#        commercial_dates_day_since_year_start  commercial_dates_year  \
# 0                                          0                   2018
# 1                                        284                   2017
# 2                                         66                   2018
# 3                                          0                   2018
# 4                                          0                   2018
# ...                                      ...                    ...
# 87849                                    358                   2017
# 87850                                     90                   2018
# 87851                                     90                   2018
# 87852                                    327                   2017
# 87853                                    358                   2017
#
#        commercial_dates_month  commercial_dates_day  \
# 0                           1                     1
# 1                          10                    12
# 2                           3                     8
# 3                           1                     1
# 4                           1                     1
# ...                       ...                   ...
# 87849                      12                    25
# 87850                       4                     1
# 87851                       4                     1
# 87852                      11                    24
# 87853                      12                    25
#
#        order_purchase_day_since_year_start  order_purchase_year  \
# 0                                       11                 2018
# 1                                      256                 2017
# 2                                       49                 2018
# 3                                       17                 2018
# 4                                        7                 2018
# ...                                    ...                  ...
# 87849                                  350                 2017
# 87850                                   93                 2018
# 87851                                   97                 2018
# 87852                                  306                 2017
# 87853                                  352                 2017
#
#        order_purchase_month  order_purchase_day  \
# 0                         1                  12
# 1                         9                  14
# 2                         2                  19
# 3                         1                  18
# 4                         1                   8
# ...                     ...                 ...
# 87849                    12                  17
# 87850                     4                   4
# 87851                     4                   8
# 87852                    11                   3
# 87853                    12                  19
#
#        commercial_date_seazonal_weight  sensitivity  \
# 0                             0.000000     0.000000
# 1                             0.000000     0.000000
# 2                            14.678600    13.587090
# 3                             0.000000     0.000000
# 4                             3.137149    12.276657
# ...                                ...          ...
# 87849                         4.880210     6.335680
# 87850                        10.360727    10.802792
# 87851                        10.360727     9.825480
# 87852                        12.756532     6.704465
# 87853                         4.880210     5.335309
#
#        mean_price_by_commercial_date  std_price_by_commercial_date  \
# 0                          92.179011                    169.492277
# 1                         116.931149                    158.173943
# 2                         106.874941                    134.596300
# 3                         108.666584                    118.364277
# 4                          82.903521                     59.651270
# ...                              ...                           ...
# 87849                     100.261696                    126.620747
# 87850                     106.242859                    104.834845
# 87851                     115.585435                    176.533677
# 87852                     204.739577                    287.452591
# 87853                     109.808333                     89.504752
#
#        commercial_date_coded  time_window_order_coded  filtered_category_coded
# 0                          7                        1                       13
# 1                          7                        1                        6
# 2                          1                        0                        8
# 3                          7                        1                        3
# 4                          9                        1                        9
# ...                      ...                      ...                      ...
# 87849                      6                        0                       13
# 87850                      8                        1                        6
# 87851                      8                        1                        2
# 87852                      0                        0                       11
# 87853                      6                        2                       10
#
# [87853 rows x 18 columns]

# %%
visualize_scores(df, sample_percentual=20, initial_range=2, final_range=7, score_types=score_types, per_col=3)

# %%
visualize_scores(df, sample_percentual=20, scaler="minmax", initial_range=2, final_range=7, score_types=score_types, per_col=3)

# %%
visualize_scores(df, sample_percentual=20, scaler="standard", initial_range=2, final_range=7, score_types=score_types, per_col=3)
# Out:
# c:\Users\gron7\faculdade\cadeiras\2024.1\proj 3\Olist-Brazilian-E-Commerce\venv\lib\site-packages\yellowbrick\utils\kneed.py:156: YellowbrickWarning: No 'knee' or 'elbow point' detected This could be due to bad clustering, no actual clusters being formed etc.
#   warnings.warn(warning_message, YellowbrickWarning)
# c:\Users\gron7\faculdade\cadeiras\2024.1\proj 3\Olist-Brazilian-E-Commerce\venv\lib\site-packages\yellowbrick\cluster\elbow.py:374: YellowbrickWarning: No 'knee' or 'elbow' point detected, pass `locate_elbow=False` to remove the warning
#   warnings.warn(warning_message, YellowbrickWarning)
