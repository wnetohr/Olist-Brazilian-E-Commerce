# %%
import seaborn as sns
import pandas as pd
import numpy as np
from math import ceil
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score
from yellowbrick.cluster import KElbowVisualizer, SilhouetteVisualizer
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.decomposition import PCA
from cluster_tools import *

random_state = 42
score_types=["silhouette", "calinski_harabasz", "davies_bouldin"]

# %%
df_original = pd.read_parquet(path="./../../data/cluster_data/category_seasonal_data.parquet")
df = df_original.copy()
df
# Out:
#        comdate_diff   price  freight_value  \
# 0                11  289.00          46.48
# 1               -28  259.90          22.31
# 2               -17   14.99           7.78
# 3                17   25.00          14.10
# 4                 7   99.90          22.57
# ...             ...     ...            ...
# 87849            -8   55.00          20.88
# 87850             3  114.90          14.16
# 87851             7   37.00          19.04
# 87852           -21  689.00          22.07
# 87853            -6   13.99           7.78
#
#        commercial_dates_day_since_year_start  commercial_dates_year  \
# 0                                          0                   2018
# 1                                        284                   2017
# 2                                         66                   2018
# 3                                          0                   2018
# 4                                          0                   2018
# ...

# %%
visualize_scores(df, sample_percentual=20, scaler="minmax", initial_range=2, final_range=7, score_types=score_types, per_col=3)

# %%
visualize_scores(df, sample_percentual=20, scaler="minmax", initial_range=2, final_range=7, score_types=score_types, per_col=3)

# %%
visualize_scores(df, sample_percentual=20, scaler="minmax", initial_range=2, final_range=7, score_types=score_types, per_col=3)

# %%
visualize_scores(df, sample_percentual=20, scaler="minmax", initial_range=2, final_range=7, score_types=score_types, per_col=3)
